# %% [markdown]
# # 25Sept: Kippenhahn Diagrams
# Make kippenhahn diagrams (both types from star explore) - early agb
# * find 1st thermal pulse
# * plot abund profiles of relevant mass range before, during, after pulse

# %% [markdown]
# ## Setup as per usual

# %%
# %pylab
from nugridpy import nugridse as mp
from nugridpy import mesa as ms
from nugridpy import astronomy as ast
import matplotlib.pyplot as plt
import numpy as np
data_dir="/data/nugrid_apod2"    
ms.set_nugrid_path(data_dir)
mp.set_nugrid_path(data_dir)
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Get evolution data from ms, to find AGB.
# Get profile data from mp to plot abundances.

# %%
s_evol = ms.star_log(mass=7,Z=0.02)
star = mp.se(mass=7,Z=0.02)
# Out:
# nugrid_path = /data/nugrid_apod2
# closest set is set1.2 (Z = 0.02)
# closest mass is 7.0
# Using old star.logsa file ...
#  reading ...100%
#
# nugrid_path = /data/nugrid_apod2
# closest set is set1.2 (Z = 0.02)
# closest mass is 7.0
# Searching files, please wait.......
# Reading preprocessor files
# File search complete.

# %% [markdown]
# ### HRD if I want it
#
# ifig=100;close(ifig);figure(ifig)
# s_evol.hrd_new()
# legend(loc='lower right').draw_frame(False)
# annotate('pre-MS', xy=(4,3), xytext=(4.2,2.75), arrowprops=dict(fc='k', shrink=0.01))
# annotate('MS', xy=(4.27,3.5), xytext=(4.3,4), arrowprops=dict(fc='k', shrink=0.01))
# annotate('subgiant branch', xy=(4,3.7), xytext=(4.14,4.1), arrowprops=dict(fc='k', shrink=0.01))
# annotate('RGB', xy=(3.61,3.41), xytext=(3.48,3.25), arrowprops=dict(fc='k', shrink=0.01))
# annotate('horizontal branch', xy=(3.76,3.74), xytext=(3.9,4.3), arrowprops=dict(fc='k', shrink=0.01))
# annotate('AGB', xy=(3.53,4.2), xytext=(3.4,4.1), arrowprops=dict(fc='k', shrink=0.01))

# %% [markdown]
# ## Thermal Pulse AGB: Evolutionary Overview
# ### Luminosity and Kippenhahn Diagrams

# %%
ifig=101;close(ifig);figure(ifig)
s_evol.plot('model_number','log_L', shape=':')
s_evol.plot('model_number','log_LH', shape=':')
s_evol.plot('model_number','log_LHe', shape=':')
xlim(0,15000)
ylim(-20,15)
title('Evolutionary Overview of Luminosity')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ifig=102;close(ifig);figure(ifig)
s_evol.plot('model_number','log_L', shape=':')
s_evol.plot('model_number','log_LH', shape=':')
s_evol.plot('model_number','log_LHe', shape=':')
xlim(1000,3900)
ylim(0.5,7)
title('Locating the AGB: Thermal Pulse Closeup')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Looks like thermal pulses begin around model 2150?
# More info: look at Kippenhahn diagram. (zoom in to same model range)

# %%
ifig=103;close(ifig);figure(ifig)
s_evol.kip_cont(ifig=ifig, xlims=[1000,3900], ylims=[1.0632,1.0679],  xres=5000)
legend(loc='lower right')
# Out:
# <img src="data:image/png;base64,..." width="640">
#  creating color map burn ...100%
#
#  creating color map mix ...100%
#
# engenstyle was  full
# mixstyle was  full
#
#  finished preparing color map
# plot versus model number
# plotting contours
# plotting patches
# plotting abund boundaries

# %% [markdown]
# ## Abundances Throughout Thermal Pulse
#
# From the Kippenhahn and luminosity plots:
# * Start of the AGB before any pulses: model 1700
# * I'm not sure about the pulse from 2100-2300
#    * (shows up in L but doesn't produce convective pocket).
#    * Ignore this one and work with the first convective pocket.
# * Right before a definite pulse: 2500
# * Peak of that pulse: 2660
# * Right after that pulse: 2750
# * Interpulse (LHe valley): 2930
#
# I will plot the pre-pulse AGB zoomed out to show overview (location of H/He-free core, H/He-burning shells, etc)
# Everything else will be zoomed in on the pulse region.

# %%
species=['H-1','He-4','C-12','C-13','N-14','O-16']

# %%
ifig=104;close(ifig);figure(ifig)
star.abu_profile(isos=species, ifig=ifig, fname=1700, logy=True)
title('Abundances on AGB Before Pulses Begin (c=1700)')
xlim(-0.1,2.5)
ylim(-100,5)
# Out:
# <img src="data:image/png;base64,..." width="640">
#  reading ['iso_massf']...100%
# (-100, 5)

# %% [markdown]
# All of the abundance plots will have this overall shape,
# so the rest will be plotted just to show the interesting region around the H and He shells.

# %%
ifig=105;close(ifig);figure(ifig)
star.abu_profile(isos=species, ifig=ifig, fname=2500, logy=True)
title('Abundances Preceding an Early Pulse (c=2500)')
xlim(1.06, 1.07)
ylim(-30,5)
# Out:
# <img src="data:image/png;base64,..." width="640">
#  reading ['iso_massf']...100%
# (-30, 5)

# %%
ifig=106;close(ifig);figure(ifig)
star.abu_profile(isos=species, ifig=ifig, fname=2660, logy=True)
title('Abundances at Thermal Pulse Peak (c=2660)')
xlim(1.06, 1.07)
ylim(-30,5)
# Out:
# <img src="data:image/png;base64,..." width="640">
#  reading ['iso_massf']...100%
# (-30, 5)

# %%
ifig=107;close(ifig);figure(ifig)
star.abu_profile(isos=species, ifig=ifig, fname=2750, logy=True)
title('Abundances Right After Pulse (c=2750)')
xlim(1.06, 1.07)
ylim(-30,5)
# Out:
# <img src="data:image/png;base64,..." width="640">
#  reading ['iso_massf']...100%
# (-30, 5)

# %%
ifig=108;close(ifig);figure(ifig)
star.abu_profile(isos=species, ifig=ifig, fname=2930, logy=True)
title('Abundances in Interpulse (L_He valley) (c=2930)')
xlim(1.06, 1.07)
ylim(-30,5)
# Out:
# <img src="data:image/png;base64,..." width="640">
#  reading ['iso_massf']...100%
# (-30, 5)
