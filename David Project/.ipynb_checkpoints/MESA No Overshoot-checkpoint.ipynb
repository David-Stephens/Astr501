# %%
# %pylab 
from nugridpy import nugridse as mp
from nugridpy import mesa as ms
import matplotlib.pyplot as plt
import numpy as np

data_dir="/user/ast501/dstephens/1M_pre_ms_to_wd/LOGS/"    

ms.set_nugrid_path(data_dir)
mp.set_nugrid_path(data_dir)
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['entropy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
star = ms.star_log(data_dir)
# Out:
# No history.datasa file found, create new one from history.data
#  reading ...100%

# %%
# create a kippenhahn diagram
plt.figure(1)
star.kippenhahn_CO(1,'model')

# look at the convection zones
plt.xlim([14000,16000])
plt.ylim([0.5,0.58])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.5, 0.58)

# %%
# grab the mesa profile data (15250)
star_prof = ms.mesa_profile(data_dir,num=15250)
# Out:
# 100 in profiles.index file ...
# Found and load nearest profile for cycle 15250
# reading /user/ast501/dstephens/1M_pre_ms_to_wd/LOGS//profile46.data ...
#  reading ...100%
#
# Closing profile tool ...

# %%
# check the dels for convection as well as any other sources of D
mass = star_prof.get('mass')
diffusion_mlt = star_prof.get('log_D_conv')
diffusion_mix = star_prof.get('log_D_thrm')
del_rad = star_prof.get('gradr')
del_ad = star_prof.get('grada')

plt.figure(3)
plt.plot(mass,diffusion_mlt,'b-')
plt.plot(mass,diffusion_mix,'k-')

# create a new axis for the dels
ax1 = plt.gca()
ax2 = ax1.twinx()

ax2.plot(mass,del_rad,'r--')
ax2.plot(mass,del_ad,'g--')

# limit to the first convection zone
ax1.set_xlim([0.52,0.6])
ax1.set_ylim([0,20])

# limit the dels
ax2.set_ylim([0,10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 10)

# %%
# check the entropy
entropy = star_prof.get('entropy')

plt.figure(2)
plt.plot(mass,diffusion_mlt)

# create a new axis for plotting entropy
ax1 = plt.gca()
ax2 = ax1.twinx()

ax2.plot(mass,entropy,'r--')

# limit to the first convection zone
ax1.set_xlim([0.52,0.6])
ax1.set_ylim([0,20])

# labels
ax1.set_ylabel('Diffusion Coefficient')
ax2.set_ylabel('Entropy')

# get axis xlim
conv_xlim = ax1.get_xlim()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# different model number, not one with the convection zone but c13 pocket
star_prof2 = ms.mesa_profile(data_dir,15000)
# Out:
# 100 in profiles.index file ...
# Found and load nearest profile for cycle 15000
# reading /user/ast501/dstephens/1M_pre_ms_to_wd/LOGS//profile39.data ...
#  reading ...100%

# %%
# plot some of the abundances
o16 = star_prof2.get('o16')
h1 = star_prof2.get('h1')
he4 = star_prof2.get('he4')
n14 = star_prof2.get('n14')
ne22 = star_prof2.get('ne22')
mass = star_prof2.get('mass')

plt.figure(4)
plt.plot(mass,np.log10(h1),label='h1')
plt.plot(mass,np.log10(he4),label='he4')
plt.plot(mass,np.log10(o16),label='o16')
plt.plot(mass,np.log10(ne22),label='ne22')
plt.plot(mass,np.log10(n14),label='n14')

# set limits
plt.ylim([-7,0])
plt.xlim(conv_xlim)

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log10
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10

# %%
o16
# Out:
# array([ 0.00932381,  0.00932381,  0.00932381, ...,  0.65755362,
#         0.65755361,  0.65755361])

# %%
ms.mesa_profile?

# %%
star_prof.cols
# Out:
# {'abar': 37,
#  'burn_ar': 89,
#  'burn_c': 81,
#  'burn_ca': 90,
#  'burn_cr': 92,
#  'burn_fe': 93,
#  'burn_mg': 86,
#  'burn_n': 82,
#  'burn_na': 85,
#  'burn_ne': 84,
#  'burn_o': 83,
#  'burn_s': 88,
#  'burn_si': 87,
#  'burn_ti': 91,
#  'c12': 71,
#  'c12_c12': 94,
#  'c12_o16': 95,
#  'cno': 79,
#  'co56_fe56': 100,
#  'conv_vel_div_csound': 51,
#  'csound': 15,
#  'd_lnepsnuc_dlnT': 43,
#  'd_lnepsnuc_dlnd': 42,
#  'dm': 19,
#  'dq_ratio': 21,
#  'entropy': 13,
#  'eps_grav': 7,
#  'eps_nuc': 40,
#  'eta': 17,
#  'free_e': 33,
#  'gradT': 60,
#  'gradT_sub_grada': 47,
#  'grada': 32,
#  'gradr': 61,
#  'h1': 68,
#  'he3': 69,
#  'he4': 70,
#  'logP': 4,
#  'logPgas': 31,
#  'logR': 5,
#  'logRho': 3,
#  'logT': 2,
#  'log_D_conv': 54,
#  'log_D_minimum': 59,
#  'log_D_mix': 49,
#  'log_D_ovr': 57,
#  'log_D_semi': 56,
#  'log_D_soft': 55,
#  'log_D_thrm': 58,
#  'log_abs_eps_grav_dm_div_L': 8,
#  'log_abs_eps_nuc': 41,
#  'log_conv_vel': 50,
#  'log_mlt_D_mix': 52,
# ...

# %%
star_prof.log_ind
# Out:
# {1: 1,
#  267: 7,
#  291: 8,
#  324: 10,
#  1000: 24,
#  2000: 44,
#  3000: 64,
#  4000: 84,
#  5000: 5,
#  6000: 29,
#  7000: 50,
#  8000: 71,
#  8603: 85,
#  9000: 93,
#  9088: 95,
#  9164: 98,
#  10000: 20,
#  11000: 42,
#  12000: 65,
#  13000: 88,
#  13450: 100,
#  13500: 2,
#  13550: 3,
#  13600: 4,
#  13650: 6,
#  13700: 9,
#  13750: 11,
#  13800: 12,
#  13850: 13,
#  13900: 14,
#  13950: 15,
#  14000: 16,
#  14050: 17,
#  14100: 18,
#  14150: 19,
#  14200: 21,
#  14250: 22,
#  14300: 23,
#  14350: 25,
#  14400: 26,
#  14450: 27,
#  14500: 28,
#  14550: 30,
#  14600: 31,
#  14650: 32,
#  14700: 33,
#  14750: 34,
#  14800: 35,
#  14850: 36,
#  14900: 37,
#  14950: 38,
#  15000: 39,
#  15050: 40,
#  15100: 41,
#  15150: 43,
#  15200: 45,
#  15250: 46,
#  15300: 47,
#  15350: 48,
#  15400: 49,
#  15450: 51,
#  15500: 52,
#  15550: 53,
#  15600: 54,
#  15650: 55,
#  15700: 56,
#  15750: 57,
#  15800: 58,
#  15850: 59,
#  15900: 60,
#  15950: 61,
#  16000: 62,
#  16050: 63,
# ...
