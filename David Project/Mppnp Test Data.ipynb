# %%
# %pylab 
from nugridpy import nugridse as mp
from nugridpy import mesa as ms
import matplotlib.pyplot as plt

data_dir="/data/nugrid_apod2"    

ms.set_nugrid_path(data_dir)
mp.set_nugrid_path(data_dir)
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# read in the nucleosynthesis data of M2, Z=2e-2
nugrid_pp = mp.se(mass=2,Z=0.02)
# Out:
# nugrid_path = /data/nugrid_apod2
# closest set is set1.2 (Z = 0.02)
# closest mass is 2.0
# Searching files, please wait.......
# Reading preprocessor files
# File search complete.

# %%
# create an abundance plot at model number 40700
species = ['H-1','He-4','C-12','C-13','O-16','Ba-138']
frame = 41100

# create figure
plt.figure(1)
nugrid_pp.abu_profile(isos=species,ifig=1,fname=frame,logy=True)

# set the ylim
plt.ylim([-10,0])
# plt.xlim([0.6005,0.6030])
# Out:
# <img src="data:image/png;base64,..." width="640">
#  reading ['iso_massf']...100%
# (-10, 0)

# %%
# read in from mppnp run
data_dir = '/user/ast501/dstephens/mppnp/NuPPN/examples/2M_ISOTOPE_OUTPUT_CHANGES/H5_out/'

mppnp_pp = mp.se(sedir=data_dir)
# Out:
# Searching files, please wait.......
# Reading preprocessor files
# File search complete.

# %%
# create figure
plt.figure(2)
mppnp_pp.abu_profile(isos=species,ifig=2,fname=frame,logy=True)

# set the ylim
plt.ylim([-10,0])
# plt.xlim([0.6005,0.6030])
# Out:
# <img src="data:image/png;base64,..." width="640">
#  reading ['iso_massf']...100%
# (-10, 0)

# %%
mass = mppnp_pp.get(frame,'mass')
rho = mppnp_pp.get(frame,'rho')
# Out:
#  reading ['rho']...100%%

# %%
# plot rho vs mass to see mass range
plt.figure(10)
plt.plot(mass,np.log(rho))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# check a histogram of mass
plt.figure(11)
plt.hist(mass,bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([   3.,    4.,    2.,   15.,   18.,   33.,   31.,   43.,   40.,
#           46.,   35.,   52.,   49.,  406.,  779.,   17.,    8.,    7.,
#            4.,    3.,    4.,    2.,    3.,    2.,    2.,    2.,    2.,
#            2.,    1.,    1.,    2.,    1.,    2.,    2.,    1.,    2.,
#            1.,    2.,    1.,    2.,    1.,    2.,    1.,    2.,    2.,
#            1.,    2.,    2.,    1.,    2.,    2.,    1.,    2.,    2.,
#            2.,    2.,    2.,    1.,    2.,    1.,    1.,    2.,    1.,
#            2.,    2.,    1.,    2.,    1.,    1.,    2.,    1.,    1.,
#            2.,    1.,    2.,    1.,    2.,    2.,    1.,    2.,    2.,
#            2.,    2.,    3.,    1.,    2.,    2.,    3.,    2.,    2.,
#            4.,    3.,    3.,    4.,    5.,    6.,    7.,    8.,   27.,   86.]),
#  array([ 0.39801766,  0.41267074,  0.42732382,  0.44197691,  0.45662999,
# ...

# %%
species
# Out:
# ['H-1', 'He-4', 'C-12', 'C-13', 'O-16', 'Ba-138']

# %%
# species that have data
mppnp_pp.se.elements
# Out:
# ['Neutron',
#  'H',
#  'He',
#  'Be',
#  'B',
#  'Li',
#  'C',
#  'B',
#  'C',
#  'N',
#  'C',
#  'N',
#  'O',
#  'F',
#  'Ne',
#  'Na',
#  'Mg',
#  'Al',
#  'Si',
#  'P',
#  'S',
#  'Be',
#  'O',
#  'Na',
#  'Al',
#  'P',
#  'Pb',
#  'Bi',
#  'Po',
#  'F',
#  'Ne',
#  'Na',
#  'Mg',
#  'Al',
#  'Si',
#  'P',
#  'S',
#  'Cl',
#  'Ar',
#  'K',
#  'Ca',
#  'Sc',
#  'Ti',
#  'V',
#  'Cr',
#  'Mn',
#  'Fe',
#  'Co',
#  'Ni',
#  'Cu',
#  'Zn',
#  'Ga',
#  'Ge',
#  'As',
#  'Se',
#  'Br',
#  'Kr',
#  'Rb',
#  'Sr',
#  'Y',
#  'Zr',
#  'Nb',
#  'Mo',
#  'Tc',
#  'Ru',
#  'Rh',
#  'Pd',
#  'Ag',
#  'Cd',
#  'In',
#  'Sn',
#  'Sb',
#  'Te',
#  'I',
#  'Xe',
#  'Cs',
#  'Ba',
#  'La',
#  'Ce',
#  'Pr',
#  'Nd',
#  'Pm',
#  'Sm',
#  'Eu',
#  'Gd',
#  'Tb',
#  'Dy',
#  'Ho',
#  'Er',
#  'Tm',
#  'Yb',
#  'Lu',
#  'Hf',
#  'Ta',
#  'W',
#  'Re',
#  'Os',
#  'Ir',
#  'Pt',
#  'Au',
#  'Hg',
#  'Tl',
#  'Pb',
#  'Bi',
#  'Al',
#  'Kr',
#  'Cd',
#  'Lu',
#  'Ta']
