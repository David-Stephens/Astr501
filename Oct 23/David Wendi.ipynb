# %% [markdown]
# ## Initialize session

# %%
# %pylab 
from nugridpy import nugridse as mp
from nugridpy import mesa as ms

data_dir="/data/nugrid_apod2"    

ms.set_nugrid_path(data_dir)
mp.set_nugrid_path(data_dir)

# %% [markdown]
# ## Mesa Profiles
#
# Get the mesa profile for the 3 M$_{\odot}$ star and look at the $\nabla$'s

# %%
# model number to look at
model_number = 69000
data = ms.mesa_profile(mass=3,Z=0.02,num=model_number)

# check the dels
dela = data.get('grada')
delr = data.get('gradr')
delt = data.get('gradT')

# grab the radius
r = data.get('logR')

# grab the mass
mass = data.get('mass')

# get the entropy
entropy = data.get('entropy')
# Out:
# nugrid_path = /data/nugrid_apod2
# closest set is set1.2 (Z = 0.02)
# closest mass is 3.0
# 100 in profiles.index file ...
# Found and load nearest profile for cycle 69000
# reading /data/nugrid_apod2/data/set1ext/set1.2/see_wind/M3.00Z2.0e-02/LOGS/log14.data ...
#  reading ...100%
#
# Closing profile tool ...

# %%
# create plot
plt.figure(1)

# plot
plt.plot(mass,dela)
plt.plot(mass,delr)
plt.plot(mass,delt,':')

# create ylim and xlim
plt.ylim([0,1])
plt.xlim([0,1.75])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 1.75)

# %%
# create an entropy plot
plt.figure(2)

# plot
plt.plot(mass,entropy)

# create xlim
plt.xlim([0,1.75])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 1.75)

# %%
# all of the columns that the data can take
data.cols
# Out:
# {'abar': 31,
#  'b8': 61,
#  'be7': 60,
#  'burn_ar': 83,
#  'burn_c': 75,
#  'burn_ca': 84,
#  'burn_cr': 86,
#  'burn_fe': 87,
#  'burn_mg': 80,
#  'burn_n': 76,
#  'burn_na': 79,
#  'burn_ne': 78,
#  'burn_o': 77,
#  'burn_s': 82,
#  'burn_si': 81,
#  'burn_ti': 85,
#  'c12': 62,
#  'c12_c12': 88,
#  'c12_o16': 89,
#  'c13': 63,
#  'cno': 73,
#  'conv_vel_div_csound': 41,
#  'csound': 14,
#  'dlnT_dt': 47,
#  'dlnd_dt': 46,
#  'dq_ratio': 19,
#  'entropy': 12,
#  'eps_grav': 7,
#  'eps_nuc': 34,
#  'eta': 16,
#  'f19': 70,
#  'free_e': 30,
#  'gradT': 44,
#  'gradT_sub_grada': 38,
#  'grada': 29,
#  'gradr': 45,
#  'h1': 55,
#  'h2': 56,
#  'he3': 57,
#  'he4': 58,
#  'li7': 59,
#  'logP': 4,
#  'logPgas': 28,
#  'logR': 5,
#  'logRho': 3,
#  'logT': 2,
#  'log_D_mix': 39,
#  'log_conv_vel': 40,
#  'log_mlt_D_mix': 42,
#  'log_opacity': 33,
#  'logdq': 18,
#  'logtau': 25,
#  'logxm': 53,
#  'logxq': 52,
#  'luminosity': 6,
#  'mass': 50,
#  'mixing_type': 13,
# ...

# %%
# the data log indexes that can be accessed
data.log_ind
# Out:
# {66000: 100,
#  67000: 42,
#  68000: 75,
#  69000: 14,
#  70000: 55,
#  71000: 7,
#  72000: 38,
#  73000: 82,
#  74000: 33,
#  75000: 80,
#  75800: 31,
#  76000: 35,
#  76600: 64,
#  77000: 88,
#  77500: 21,
#  78000: 58,
#  78700: 93,
#  78800: 95,
#  78900: 32,
#  79000: 49,
#  79200: 53,
#  80000: 63,
#  81000: 9,
#  81200: 51,
#  81600: 89,
#  81700: 65,
#  81900: 83,
#  82000: 74,
#  82700: 1,
#  82800: 10,
#  83000: 12,
#  83100: 13,
#  83300: 15,
#  83500: 20,
#  84000: 24,
#  84400: 26,
#  84600: 27,
#  85000: 37,
#  86000: 47,
#  87000: 57,
#  88000: 67,
#  89000: 77,
#  90000: 87,
#  91000: 97,
#  91800: 8,
#  92000: 23,
#  93000: 36,
#  93300: 48,
#  94000: 59,
#  95000: 70,
#  95400: 81,
#  96000: 92,
#  97000: 4,
#  98000: 19,
#  99000: 34,
#  100000: 46,
#  101000: 60,
#  102000: 72,
#  103000: 84,
#  104000: 96,
#  105000: 11,
#  106000: 30,
#  107000: 43,
#  108000: 56,
#  109000: 71,
#  110000: 85,
#  111000: 99,
#  112000: 17,
#  113000: 2,
#  114000: 22,
# ...
