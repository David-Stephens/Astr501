# %%
# %pylab
from nugridpy import mesa as ms
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
m7=ms.star_log('/user/ast501/mesa/7M_prems_to_AGB/LOGS')
# Out:
# Using old history.datasa file ...
#  reading ...100%
#
# Closing history.data  tool ...

# %%
figure(1)
m7.hrd_new()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
m7.kippenhahn(2,'model')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
m7.cols.keys()
# Out:
# dict_keys(['star_age', 'surface_o16', 'epsnuc_M_6', 'num_retries', 'epsnuc_M_3', 'luminosity', 'neutron_rich_core_mass', 'log_R', 'log_Lnuc', 'center_c12', 'v_div_csound_surf', 'tri_alfa', 'conv_mx1_top', 'log_g', 'log_center_P', 'mx1_top', 'log_LHe', 'conv_mx2_top', 'center_abar', 'si_core_mass', 'mx2_top', 'log_center_T', 'pp', 'fe_core_mass', 'epsnuc_M_8', 'center_h1', 'star_mass', 'num_backups', 'conv_mx2_bot', 'conv_mx1_bot', 'log_Teff', 'center_o16', 'epsnuc_M_4', 'center_he4', 'center_mu', 'log_xmstar', 'log_L', 'center_ye', 'log_center_Rho', 'o_core_mass', 'log_dt', 'total_mass_he4', 'surface_c12', 'gravity', 'model_number', 'cno', 'epsnuc_M_5', 'mass_conv_core', 'c_core_mass', 'he_core_mass', 'epsnuc_M_2', 'log_LH', 'mx2_bot', 'num_zones', 'mx1_bot', 'epsnuc_M_7', 'log_LZ', 'epsnuc_M_1', 'total_mass_h1', 'log_abs_mdot'])

# %%
[ print(thing) for thing in m7.cols.keys() if 'h1' in thing]
# Out:
# center_h1
# total_mass_h1
# [None, None]

# %%
figure(5)
m7.plot('model_number', 'center_h1')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
p=ms.mesa_profile("/user/ast501/mesa/7M_prems_to_AGB/LOGS",1400)
# Out:
# 58 in profiles.index file ...
# Found and load nearest profile for cycle 1400
# reading /user/ast501/mesa/7M_prems_to_AGB/LOGS/profile32.data ...
#  reading ...100%

# %%
p.log_ind
# Out:
# {1: 1,
#  50: 2,
#  100: 3,
#  150: 4,
#  200: 5,
#  250: 6,
#  300: 7,
#  350: 8,
#  400: 9,
#  450: 10,
#  500: 11,
#  550: 12,
#  600: 13,
#  650: 14,
#  700: 15,
#  750: 16,
#  800: 17,
#  850: 18,
#  900: 19,
#  950: 20,
#  955: 21,
#  1000: 22,
#  1050: 23,
#  1100: 24,
#  1134: 25,
#  1150: 26,
#  1200: 27,
#  1217: 28,
#  1250: 29,
#  1300: 30,
#  1350: 31,
#  1400: 32,
#  1450: 33,
#  1500: 34,
#  1550: 35,
#  1554: 36,
#  1600: 37,
#  1650: 38,
#  1700: 39,
#  1750: 40,
#  1772: 41,
#  1800: 42,
#  1850: 43,
#  1900: 44,
#  1950: 45,
#  2000: 46,
#  2034: 47,
#  2050: 48,
#  2100: 49,
#  2150: 50,
#  2200: 51,
#  2250: 52,
#  2300: 53,
#  2350: 54,
#  2400: 55,
#  2450: 56,
#  2500: 57,
#  2542: 58}

# %%
p.cols
# Out:
# {'abar': 37,
#  'burn_ar': 89,
#  'burn_c': 81,
#  'burn_ca': 90,
#  'burn_cr': 92,
#  'burn_fe': 93,
#  'burn_mg': 86,
#  'burn_n': 82,
#  'burn_na': 85,
#  'burn_ne': 84,
#  'burn_o': 83,
#  'burn_s': 88,
#  'burn_si': 87,
#  'burn_ti': 91,
#  'c12': 71,
#  'c12_c12': 94,
#  'c12_o16': 95,
#  'cno': 79,
#  'co56_fe56': 100,
#  'conv_vel_div_csound': 51,
#  'csound': 15,
#  'd_lnepsnuc_dlnT': 43,
#  'd_lnepsnuc_dlnd': 42,
#  'dm': 19,
#  'dq_ratio': 21,
#  'entropy': 13,
#  'eps_grav': 7,
#  'eps_nuc': 40,
#  'eta': 17,
#  'free_e': 33,
#  'gradT': 60,
#  'gradT_sub_grada': 47,
#  'grada': 32,
#  'gradr': 61,
#  'h1': 68,
#  'he3': 69,
#  'he4': 70,
#  'logP': 4,
#  'logPgas': 31,
#  'logR': 5,
#  'logRho': 3,
#  'logT': 2,
#  'log_D_conv': 54,
#  'log_D_minimum': 59,
#  'log_D_mix': 49,
#  'log_D_ovr': 57,
#  'log_D_semi': 56,
#  'log_D_soft': 55,
#  'log_D_thrm': 58,
#  'log_abs_eps_grav_dm_div_L': 8,
#  'log_abs_eps_nuc': 41,
#  'log_conv_vel': 50,
#  'log_mlt_D_mix': 52,
# ...
